# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample_mean = 5.2
population_mean = 5
population_stddev = 1
sample_size = 100

# Calculate the z-test statistic
z = (sample_mean - population_mean) / (population_stddev / np.sqrt(sample_size))

# Calculate the p-value
p_value = 1 - norm.cdf(z)

# Set the significance level (alpha)
alpha = 0.05

# Perform the z-test
if p_value < alpha:
    print("Reject the null hypothesis. The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis. The sample mean is not significantly different from the population mean.")
# Out:
# Reject the null hypothesis. The sample mean is significantly different from the population mean.

# %% [markdown]
# With dataset

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm

#load the dataset
data = pd.read_csv('/content/california_housing_train[1].csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# Extract the relevant data for comparison
sample_data = data['total_rooms']  # Sample data to be tested
population_mean = 5  # Known population mean
population_stddev = 1  # Known population standard deviation

# Calculate the sample statistics
sample_mean = np.mean(data['total_bedrooms'])  # Sample mean
sample_size = len('total_bedrooms')  # Sample size

# Calculate the z-test statistic
z = (sample_mean - population_mean) / (population_stddev / np.sqrt(sample_size))

# Calculate the p-value
p_value = 1 - norm.cdf(z)

# Set the significance level (alpha)
alpha = 0.05

#perform the z-test
if p_value < alpha:
  print ("Reject the null hypothesis.the sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis. the sample mean is not significantly different from the population mean.")
# Out:
# Reject the null hypothesis.the sample mean is significantly different from the population mean.
